# %%
import geopandas as gpd
from matplotlib import pyplot
import numpy
import earthpy as et
import rasterio as rio
from rasterio.plot import show

# %%
path_groundtruth='/home/robert/ds-field-boundaries/data/shapefile/'

# %%
open_file=gpd.read_file(path_groundtruth+'french_farms_full_cliped.shp')

# %%
open_file.plot()

# %%
open_file
# Out:
#        ID_PARCEL  SURF_PARC CODE_CULTU CODE_GROUP CULTURE_D1 CULTURE_D2  \
# 0         144740       3.43        PPH         18       None       None
# 1         144733       0.39        BTH          1       None       None
# 2         144735       1.41        BTH          1       None       None
# 3         177363       0.03        SNE         28       None       None
# 4         144734       0.40        PPH         18       None       None
# ...          ...        ...        ...        ...        ...        ...
# 130273  11383914       7.70        BTH          1       None       None
# 130274   9321674       6.32        CZH          5       None       None
# 130275   9321749       0.97        SNE         28       None       None
# 130276   9321752       0.54        SNE         28       None       None
# 130277   9321750       0.69        SNE         28       None       None
#
#                                                  geometry
# ...

# %%
save_path="/home/robert/ds-wildfire/data/training_patches"
excluded_path="/home/robert/ds-wildfire/excluded.txt"
all_extracted_path="/home/robert/ds-wildfire/data/extracted/patches"
path_to_anno_source="/home/robert/ds-wildfire/data/extracted/anno"

# %%
import os
import pickle
import shutil
from pathlib import Path
from docopt import docopt

from PIL import Image as pilimage
import numpy as np

# %%
import os
import pickle
import shutil
from pathlib import Path
from docopt import docopt
from patchutils.coco import coco_to_shapely
from PIL import Image as pilimage
import numpy as np


def dump_polygons(annotation_dir_source, save_path, included):
    """

    :param annotation_dir_source: 
    :param save_path: Path to file to save the annotations used for pipelines and testing eg polygons.pkl
    :param included:
    :return:
    """
    # Merge multiple mgrs annotation files
    all_annotations = {}
    mgrs_anno_files = os.listdir(annotation_dir_source)
    for anno_file in mgrs_anno_files:
        anno_file = coco_to_shapely(os.path.join(annotation_dir_source, anno_file))
        all_annotations = {**all_annotations, **anno_file}

    included_annotations = {}
    for in_test_img in included:
        included_annotations[in_test_img + ".jpg"] = all_annotations[
            in_test_img + ".jpg"
        ]

    with open(save_path, "wb") as f:
        pickle.dump(included_annotations, f, pickle.HIGHEST_PROTOCOL)


def read_excluded(path):
    """
    Reads all images that are meant to be excluded and returns a list
    :param path:
    :return:
    """
    with open(path, "r") as f:
        lines = f.read().splitlines()
    lines = [line.split("\n")[0] for line in lines]
    return lines


def get_all(path):
    """
    Get all patches that have been extracted
    :param path:
    :return:
    """
    files = [f.split(".")[0] for f in os.listdir(path)]
    return files


def main(
    save_path, excluded_path, all_extracted_path, path_to_anno_source, delete=False
):
    """
    :param save_path: path where newly sorted patches and their annotations will be stored
    :param excluded_path: path to where image names that will be excluded are stored
    :param all_extracted_path: path to where all images that have been extracted from MGRS files are stored
    :param path_to_anno_source: path to where extracted source annotation files are stored
    :param delete: if all extracted (non-filtered) patches should be deleted [default=False]
    :return:
    """

    # Read files that have been selected to exclude from pipelines
    # Both all and excluded, returned without extension
    excluded_patches = read_excluded(excluded_path) if excluded_path else []
    print(len(excluded_patches))
    all_patches = get_all(all_extracted_path)

    # Make directories to store filtered patches and ground truth
    path_to_store_patches = os.path.join(save_path, "patches")
    os.makedirs(path_to_store_patches, exist_ok=True)
    path_to_store_anno = os.path.join(save_path, "anno")
    os.makedirs(path_to_store_anno, exist_ok=True)

    # Move image patches
    included = []  # To pass into dump_polygons
    for patch in all_patches:
        if np.unique(img).size > 2:
            source_patch_path = os.path.join(all_extracted_path, patch + ".jpg")
            target_patch_path = os.path.join(path_to_store_patches, patch + ".jpg")
            img = np.asarray(pilimage.open(source_patch_path))
            shutil.move(source_patch_path, target_patch_path)
            included.append(patch)
          
    print("Number of included patches {}".format(len(included)))
    # Combine and move annotations to new directory
    save_annotations_file = os.path.join(path_to_store_anno, "polygons.pkl")
    dump_polygons(path_to_anno_source, save_annotations_file, included)

    # Remove patches and their directory if not to be used for pipelines
    if delete:
        os.remove(str(Path(all_extracted_path).parents[0]))


if __name__ == "__main__":
    arguments = docopt(__doc__)
    save_path = arguments["<save_path>"]
    excluded_path = arguments["<excluded_path>"]
    all_extracted_path = arguments["<all_extracted_path>"]
    path_to_anno_source = arguments["<path_to_anno_source>"]
    main(save_path, excluded_path, all_extracted_path, path_to_anno_source)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-47-f7fa4f234c85> in <module>
#       4 from pathlib import Path
#       5 from docopt import docopt
# ----> 6 from patchutils.coco import coco_to_shapely
#       7 from PIL import Image as pilimage
#       8 import numpy as np
#
# ModuleNotFoundError: No module named 'patchutils'

# %%
img = np.asarray(pilimage.open(path))

# %%
path="/home/robert/ds-wildfire/data/training_patches/patches/raster_patch100406_31_T_GJ_2017-10-07.jpg"

# %%
for patch in all_patches:
    if np.unique(img).size > 2:
        print("hello")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-53643faa8577> in <module>
# ----> 1 for patch in all_patches:
#       2     if np.unique(img).size > 2:
#       3         print("hello")
#
# NameError: name 'all_patches' is not defined

# %%
np.unique(img).size
# Out:
# 2

# %%
included=[]
source_patch_path = os.path.join(path)
target_patch_path = os.path.join(path)
#ROBERT:test if patch is empty
img = np.asarray(pilimage.open(source_patch_path))
if np.unique(img).size > 2:
    shutil.move(source_patch_path, target_patch_path)
    included.append(patch)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-bc8686374d38> in <module>
#       6 if np.unique(img).size > 2:
#       7     shutil.move(source_patch_path, target_patch_path)
# ----> 8     included.append(patch)
#
# NameError: name 'patch' is not defined

# %%
path="/home/robert/ds-wildfire/data/extracted/patches"

# %%
files = [f.split(".")[0] for f in os.listdir(path)]

# %%
files
# Out:
# ['raster_patch101239_31_T_GJ_2017-06-16',
#  'raster_patch101281_31_T_GJ_2017-06-16',
#  'raster_patch101239_31_T_GJ_2017-07-22',
#  'raster_patch101281_31_T_GJ_2017-07-22',
#  'raster_patch100448_31_T_GJ_2017-07-26',
#  'raster_patch100449_31_T_GJ_2017-07-26',
#  'raster_patch100490_31_T_GJ_2017-07-26',
#  'raster_patch100491_31_T_GJ_2017-07-26',
#  'raster_patch100492_31_T_GJ_2017-07-26',
#  'raster_patch100532_31_T_GJ_2017-07-26',
#  'raster_patch100533_31_T_GJ_2017-07-26',
#  'raster_patch100534_31_T_GJ_2017-07-26',
#  'raster_patch100575_31_T_GJ_2017-07-26',
#  'raster_patch101239_31_T_GJ_2017-07-26',
#  'raster_patch101281_31_T_GJ_2017-07-26',
#  'raster_patch100406_31_T_GJ_2017-09-04',
#  'raster_patch100448_31_T_GJ_2017-09-04',
#  'raster_patch100449_31_T_GJ_2017-09-04',
#  'raster_patch100490_31_T_GJ_2017-09-04',
#  'raster_patch100491_31_T_GJ_2017-09-04',
#  'raster_patch100492_31_T_GJ_2017-09-04',
#  'raster_patch100532_31_T_GJ_2017-09-04',
#  'raster_patch100533_31_T_GJ_2017-09-04',
#  'raster_patch100534_31_T_GJ_2017-09-04',
#  'raster_patch100575_31_T_GJ_2017-09-04',
#  'raster_patch101239_31_T_GJ_2017-09-04',
#  'raster_patch101281_31_T_GJ_2017-09-04',
#  'raster_patch100406_31_T_GJ_2017-09-05',
#  'raster_patch100448_31_T_GJ_2017-09-05',
#  'raster_patch100449_31_T_GJ_2017-09-05',
#  'raster_patch100490_31_T_GJ_2017-09-05',
#  'raster_patch100491_31_T_GJ_2017-09-05',
#  'raster_patch100492_31_T_GJ_2017-09-05',
#  'raster_patch100532_31_T_GJ_2017-09-05',
#  'raster_patch100533_31_T_GJ_2017-09-05',
#  'raster_patch100534_31_T_GJ_2017-09-05',
#  'raster_patch100575_31_T_GJ_2017-09-05',
#  'raster_patch101239_31_T_GJ_2017-09-05',
#  'raster_patch101281_31_T_GJ_2017-09-05',
#  'raster_patch101710_31_T_GJ_2017-09-05',
#  'raster_patch100406_31_T_GJ_2017-10-09',
#  'raster_patch100448_31_T_GJ_2017-10-09',
#  'raster_patch100449_31_T_GJ_2017-10-09',
#  'raster_patch100490_31_T_GJ_2017-10-09',
#  'raster_patch100491_31_T_GJ_2017-10-09',
#  'raster_patch100492_31_T_GJ_2017-10-09',
#  'raster_patch100532_31_T_GJ_2017-10-09',
#  'raster_patch100533_31_T_GJ_2017-10-09',
#  'raster_patch100534_31_T_GJ_2017-10-09',
#  'raster_patch100575_31_T_GJ_2017-10-09',
#  'raster_patch101239_31_T_GJ_2017-10-09',
#  'raster_patch101281_31_T_GJ_2017-10-09',
#  'raster_patch101282_31_T_GJ_2017-10-09',
#  'raster_patch101324_31_T_GJ_2017-10-09',
#  'raster_patch100406_31_T_GJ_2017-10-10',
#  'raster_patch100448_31_T_GJ_2017-10-10',
#  'raster_patch100449_31_T_GJ_2017-10-10',
#  'raster_patch100490_31_T_GJ_2017-10-10',
#  'raster_patch100491_31_T_GJ_2017-10-10',
#  'raster_patch100492_31_T_GJ_2017-10-10',
#  'raster_patch100532_31_T_GJ_2017-10-10',
#  'raster_patch100533_31_T_GJ_2017-10-10',
#  'raster_patch100534_31_T_GJ_2017-10-10',
#  'raster_patch100575_31_T_GJ_2017-10-10',
#  'raster_patch101239_31_T_GJ_2017-10-10',
#  'raster_patch101281_31_T_GJ_2017-10-10',
#  'raster_patch101282_31_T_GJ_2017-10-10',
#  'raster_patch101324_31_T_GJ_2017-10-10',
#  'raster_patch101710_31_T_GJ_2017-10-10',
#  'raster_patch101140_31_T_GH_2017-07-24',
#  'raster_patch101305_31_T_GH_2017-07-24',
#  'raster_patch101306_31_T_GH_2017-07-24',
#  'raster_patch101098_31_T_GH_2017-07-26',
#  'raster_patch101099_31_T_GH_2017-07-26',
#  'raster_patch101100_31_T_GH_2017-07-26',
#  'raster_patch101140_31_T_GH_2017-07-26',
#  'raster_patch101141_31_T_GH_2017-07-26',
#  'raster_patch101142_31_T_GH_2017-07-26',
#  'raster_patch101143_31_T_GH_2017-07-26',
#  'raster_patch101183_31_T_GH_2017-07-26',
#  'raster_patch101184_31_T_GH_2017-07-26',
#  'raster_patch101185_31_T_GH_2017-07-26',
#  'raster_patch101305_31_T_GH_2017-07-26',
#  'raster_patch101306_31_T_GH_2017-07-26',
#  'raster_patch100930_31_T_GH_2017-09-04',
#  'raster_patch100931_31_T_GH_2017-09-04',
#  'raster_patch100972_31_T_GH_2017-09-04',
#  'raster_patch100973_31_T_GH_2017-09-04',
#  'raster_patch101098_31_T_GH_2017-09-04',
#  'raster_patch101099_31_T_GH_2017-09-04',
#  'raster_patch101100_31_T_GH_2017-09-04',
#  'raster_patch101140_31_T_GH_2017-09-04',
#  'raster_patch101141_31_T_GH_2017-09-04',
#  'raster_patch101142_31_T_GH_2017-09-04',
#  'raster_patch101143_31_T_GH_2017-09-04',
#  'raster_patch101183_31_T_GH_2017-09-04',
#  'raster_patch101517_31_T_GH_2017-07-26',
#  'raster_patch101517_31_T_GH_2017-09-04',
#  'raster_patch101517_31_T_GH_2017-09-05',
#  'raster_patch101517_31_T_GH_2017-09-07',
#  'raster_patch101517_31_T_GH_2017-10-07',
#  'raster_patch101517_31_T_GH_2017-10-09',
#  'raster_patch101517_31_T_GH_2017-10-10',
#  'raster_patch101558_31_T_GH_2017-06-12',
#  'raster_patch101558_31_T_GH_2017-06-16',
#  'raster_patch101558_31_T_GH_2017-06-19',
#  'raster_patch101558_31_T_GH_2017-07-22',
#  'raster_patch101558_31_T_GH_2017-07-26',
#  'raster_patch101558_31_T_GH_2017-09-04',
#  'raster_patch101558_31_T_GH_2017-07-24',
#  'raster_patch101558_31_T_GH_2017-09-05',
#  'raster_patch101558_31_T_GH_2017-09-07',
#  'raster_patch101558_31_T_GH_2017-10-07',
#  'raster_patch101558_31_T_GH_2017-10-09',
#  'raster_patch101558_31_T_GH_2017-10-10',
#  'raster_patch101559_31_T_GH_2017-09-04',
#  'raster_patch101559_31_T_GH_2017-07-26',
#  'raster_patch101559_31_T_GH_2017-09-05',
#  'raster_patch101559_31_T_GH_2017-09-07',
#  'raster_patch101559_31_T_GH_2017-10-07',
#  'raster_patch101559_31_T_GH_2017-10-10',
#  'raster_patch101559_31_T_GH_2017-10-09',
#  'raster_patch101710_31_T_GJ_2017-09-04',
#  'raster_patch101710_31_T_GJ_2017-09-07',
#  'raster_patch101710_31_T_GJ_2017-10-09',
#  'raster_patch101710_31_T_GJ_2017-10-07']

# %%
included = []  # To pass into dump_polygons
path_to_store_patches = os.path.join(save_path, "patches")
os.makedirs(path_to_store_patches, exist_ok=True)
path_to_store_anno = os.path.join(save_path, "anno")
os.makedirs(path_to_store_anno, exist_ok=True)
for patch in files:
    source_patch_path = os.path.join(all_extracted_path, patch + ".jpg")
    target_patch_path = os.path.join(path_to_store_patches, patch + ".jpg")
    #ROBERT:test if patch is empty
    img = np.asarray(pilimage.open(source_patch_path))
    if np.unique(img).size > 2:
        included.append(patch)
        shutil.move(source_patch_path, target_patch_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-61-7916e82a69b2> in <module>
#       8     target_patch_path = os.path.join(path_to_store_patches, patch + ".jpg")
#       9     #ROBERT:test if patch is empty
# ---> 10     img = np.asarray(pilimage.open(source_patch_path))
#      11     if np.unique(img).size > 2:
#      12         included.append(patch)
#
# ~/.pyenv/versions/ds-wildfire/lib/python3.8/site-packages/PIL/Image.py in open(fp, mode)
#    2841
#    2842     if filename:
# -> 2843         fp = builtins.open(filename, "rb")
#    2844         exclusive_fp = True
#    2845
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/robert/ds-wildfire/data/extracted/patches/.jpg'

# %%
patch
# Out:
# ''

# %%
files
# Out:
# ['raster_patch101239_31_T_GJ_2017-06-16',
#  'raster_patch101281_31_T_GJ_2017-06-16',
#  'raster_patch101239_31_T_GJ_2017-07-22',
#  'raster_patch101281_31_T_GJ_2017-07-22',
#  'raster_patch100448_31_T_GJ_2017-07-26',
#  'raster_patch100449_31_T_GJ_2017-07-26',
#  'raster_patch100490_31_T_GJ_2017-07-26',
#  'raster_patch100491_31_T_GJ_2017-07-26',
#  'raster_patch100492_31_T_GJ_2017-07-26',
#  'raster_patch100532_31_T_GJ_2017-07-26',
#  'raster_patch100533_31_T_GJ_2017-07-26',
#  'raster_patch100534_31_T_GJ_2017-07-26',
#  'raster_patch100575_31_T_GJ_2017-07-26',
#  'raster_patch101239_31_T_GJ_2017-07-26',
#  'raster_patch101281_31_T_GJ_2017-07-26',
#  'raster_patch100406_31_T_GJ_2017-09-04',
#  'raster_patch100448_31_T_GJ_2017-09-04',
#  'raster_patch100449_31_T_GJ_2017-09-04',
#  'raster_patch100490_31_T_GJ_2017-09-04',
#  'raster_patch100491_31_T_GJ_2017-09-04',
#  'raster_patch100492_31_T_GJ_2017-09-04',
#  'raster_patch100532_31_T_GJ_2017-09-04',
#  'raster_patch100533_31_T_GJ_2017-09-04',
#  'raster_patch100534_31_T_GJ_2017-09-04',
#  'raster_patch100575_31_T_GJ_2017-09-04',
#  'raster_patch101239_31_T_GJ_2017-09-04',
#  'raster_patch101281_31_T_GJ_2017-09-04',
#  'raster_patch100406_31_T_GJ_2017-09-05',
#  'raster_patch100448_31_T_GJ_2017-09-05',
#  'raster_patch100449_31_T_GJ_2017-09-05',
#  'raster_patch100490_31_T_GJ_2017-09-05',
#  'raster_patch100491_31_T_GJ_2017-09-05',
#  'raster_patch100492_31_T_GJ_2017-09-05',
#  'raster_patch100532_31_T_GJ_2017-09-05',
#  'raster_patch100533_31_T_GJ_2017-09-05',
#  'raster_patch100534_31_T_GJ_2017-09-05',
#  'raster_patch100575_31_T_GJ_2017-09-05',
#  'raster_patch101239_31_T_GJ_2017-09-05',
#  'raster_patch101281_31_T_GJ_2017-09-05',
#  'raster_patch101710_31_T_GJ_2017-09-05',
#  'raster_patch100406_31_T_GJ_2017-10-09',
#  'raster_patch100448_31_T_GJ_2017-10-09',
#  'raster_patch100449_31_T_GJ_2017-10-09',
#  'raster_patch100490_31_T_GJ_2017-10-09',
#  'raster_patch100491_31_T_GJ_2017-10-09',
#  'raster_patch100492_31_T_GJ_2017-10-09',
#  'raster_patch100532_31_T_GJ_2017-10-09',
#  'raster_patch100533_31_T_GJ_2017-10-09',
#  'raster_patch100534_31_T_GJ_2017-10-09',
#  'raster_patch100575_31_T_GJ_2017-10-09',
#  'raster_patch101239_31_T_GJ_2017-10-09',
#  'raster_patch101281_31_T_GJ_2017-10-09',
#  'raster_patch101282_31_T_GJ_2017-10-09',
#  'raster_patch101324_31_T_GJ_2017-10-09',
#  'raster_patch100406_31_T_GJ_2017-10-10',
#  'raster_patch100448_31_T_GJ_2017-10-10',
#  'raster_patch100449_31_T_GJ_2017-10-10',
#  'raster_patch100490_31_T_GJ_2017-10-10',
#  'raster_patch100491_31_T_GJ_2017-10-10',
#  'raster_patch100492_31_T_GJ_2017-10-10',
#  'raster_patch100532_31_T_GJ_2017-10-10',
#  'raster_patch100533_31_T_GJ_2017-10-10',
#  'raster_patch100534_31_T_GJ_2017-10-10',
#  'raster_patch100575_31_T_GJ_2017-10-10',
#  'raster_patch101239_31_T_GJ_2017-10-10',
#  'raster_patch101281_31_T_GJ_2017-10-10',
#  'raster_patch101282_31_T_GJ_2017-10-10',
#  'raster_patch101324_31_T_GJ_2017-10-10',
#  'raster_patch101710_31_T_GJ_2017-10-10',
#  'raster_patch101140_31_T_GH_2017-07-24',
#  'raster_patch101305_31_T_GH_2017-07-24',
#  'raster_patch101306_31_T_GH_2017-07-24',
#  'raster_patch101098_31_T_GH_2017-07-26',
#  'raster_patch101099_31_T_GH_2017-07-26',
#  'raster_patch101100_31_T_GH_2017-07-26',
#  'raster_patch101140_31_T_GH_2017-07-26',
#  'raster_patch101141_31_T_GH_2017-07-26',
#  'raster_patch101142_31_T_GH_2017-07-26',
#  'raster_patch101143_31_T_GH_2017-07-26',
#  'raster_patch101183_31_T_GH_2017-07-26',
#  'raster_patch101184_31_T_GH_2017-07-26',
#  'raster_patch101185_31_T_GH_2017-07-26',
#  'raster_patch101305_31_T_GH_2017-07-26',
#  'raster_patch101306_31_T_GH_2017-07-26',
#  'raster_patch100930_31_T_GH_2017-09-04',
#  'raster_patch100931_31_T_GH_2017-09-04',
#  'raster_patch100972_31_T_GH_2017-09-04',
#  'raster_patch100973_31_T_GH_2017-09-04',
#  'raster_patch101098_31_T_GH_2017-09-04',
#  'raster_patch101099_31_T_GH_2017-09-04',
#  'raster_patch101100_31_T_GH_2017-09-04',
#  'raster_patch101140_31_T_GH_2017-09-04',
#  'raster_patch101141_31_T_GH_2017-09-04',
#  'raster_patch101142_31_T_GH_2017-09-04',
#  'raster_patch101143_31_T_GH_2017-09-04',
#  'raster_patch101183_31_T_GH_2017-09-04',
#  'raster_patch101184_31_T_GH_2017-09-04',
#  'raster_patch101185_31_T_GH_2017-09-04',
#  'raster_patch101305_31_T_GH_2017-09-04',
#  'raster_patch101306_31_T_GH_2017-09-04',
#  'raster_patch100930_31_T_GH_2017-09-05',
#  'raster_patch100931_31_T_GH_2017-09-05',
#  'raster_patch100972_31_T_GH_2017-09-05',
#  'raster_patch100973_31_T_GH_2017-09-05',
#  'raster_patch101098_31_T_GH_2017-09-05',
#  'raster_patch101099_31_T_GH_2017-09-05',
#  'raster_patch101100_31_T_GH_2017-09-05',
#  'raster_patch101140_31_T_GH_2017-09-05',
#  'raster_patch101141_31_T_GH_2017-09-05',
#  'raster_patch101142_31_T_GH_2017-09-05',
#  'raster_patch101143_31_T_GH_2017-09-05',
#  'raster_patch101183_31_T_GH_2017-09-05',
#  'raster_patch101184_31_T_GH_2017-09-05',
#  'raster_patch101185_31_T_GH_2017-09-05',
#  'raster_patch101305_31_T_GH_2017-09-05',
#  'raster_patch101306_31_T_GH_2017-09-05',
#  'raster_patch100930_31_T_GH_2017-09-07',
#  'raster_patch100931_31_T_GH_2017-09-07',
#  'raster_patch100972_31_T_GH_2017-09-07',
#  'raster_patch100973_31_T_GH_2017-09-07',
#  'raster_patch101098_31_T_GH_2017-09-07',
#  'raster_patch101099_31_T_GH_2017-09-07',
#  'raster_patch101100_31_T_GH_2017-09-07',
#  'raster_patch101140_31_T_GH_2017-09-07',
#  'raster_patch101141_31_T_GH_2017-09-07',
#  'raster_patch101142_31_T_GH_2017-09-07',
#  'raster_patch101143_31_T_GH_2017-09-07',
#  'raster_patch101183_31_T_GH_2017-09-07',
#  'raster_patch101184_31_T_GH_2017-09-07',
#  'raster_patch101185_31_T_GH_2017-09-07',
#  'raster_patch101305_31_T_GH_2017-09-07',
#  'raster_patch101306_31_T_GH_2017-09-07',
#  'raster_patch100930_31_T_GH_2017-10-10',
#  'raster_patch100931_31_T_GH_2017-10-10',
#  'raster_patch101184_31_T_GH_2017-10-09',
#  'raster_patch101185_31_T_GH_2017-10-07',
#  'raster_patch101185_31_T_GH_2017-10-09',
#  'raster_patch101239_31_T_GJ_2017-06-19',
#  'raster_patch101239_31_T_GJ_2017-07-24',
#  'raster_patch101239_31_T_GJ_2017-09-07',
#  'raster_patch101239_31_T_GJ_2017-10-07',
#  'raster_patch101281_31_T_GJ_2017-06-19',
#  'raster_patch101281_31_T_GJ_2017-07-24',
#  'raster_patch101281_31_T_GJ_2017-09-07',
#  'raster_patch101281_31_T_GJ_2017-10-07',
#  'raster_patch101305_31_T_GH_2017-10-09',
#  'raster_patch101305_31_T_GH_2017-07-22',
#  'raster_patch101305_31_T_GH_2017-10-07',
#  'raster_patch101306_31_T_GH_2017-07-22',
#  'raster_patch101306_31_T_GH_2017-10-07',
#  'raster_patch101306_31_T_GH_2017-10-09',
#  'raster_patch101516_31_T_GH_2017-07-26',
#  'raster_patch101516_31_T_GH_2017-09-04',
#  'raster_patch101516_31_T_GH_2017-09-05',
#  'raster_patch101516_31_T_GH_2017-09-07',
#  'raster_patch101516_31_T_GH_2017-10-07',
#  'raster_patch101516_31_T_GH_2017-10-09',
#  'raster_patch101516_31_T_GH_2017-10-10',
#  'raster_patch101517_31_T_GH_2017-07-26',
#  'raster_patch101517_31_T_GH_2017-09-04',
#  'raster_patch101517_31_T_GH_2017-09-05',
#  'raster_patch101517_31_T_GH_2017-09-07',
#  'raster_patch101517_31_T_GH_2017-10-07',
#  'raster_patch101517_31_T_GH_2017-10-09',
#  'raster_patch101517_31_T_GH_2017-10-10',
#  'raster_patch101558_31_T_GH_2017-06-12',
#  'raster_patch101558_31_T_GH_2017-06-16',
#  'raster_patch101558_31_T_GH_2017-06-19',
#  'raster_patch101558_31_T_GH_2017-07-22',
#  'raster_patch101558_31_T_GH_2017-07-26',
#  'raster_patch101558_31_T_GH_2017-09-04',
#  'raster_patch101558_31_T_GH_2017-07-24',
#  'raster_patch101558_31_T_GH_2017-09-05',
#  'raster_patch101558_31_T_GH_2017-09-07',
#  'raster_patch101558_31_T_GH_2017-10-07',
#  'raster_patch101558_31_T_GH_2017-10-09',
#  'raster_patch101558_31_T_GH_2017-10-10',
#  'raster_patch101559_31_T_GH_2017-09-04',
#  'raster_patch101559_31_T_GH_2017-07-26',
#  'raster_patch101559_31_T_GH_2017-09-05',
#  'raster_patch101559_31_T_GH_2017-09-07',
#  'raster_patch101559_31_T_GH_2017-10-07',
#  'raster_patch101559_31_T_GH_2017-10-10',
#  'raster_patch101559_31_T_GH_2017-10-09',
#  'raster_patch101710_31_T_GJ_2017-09-04',
#  'raster_patch101710_31_T_GJ_2017-09-07',
#  'raster_patch101710_31_T_GJ_2017-10-09',
#  'raster_patch101710_31_T_GJ_2017-10-07']

# %%
path = "/home/robert/ds-wildfire/data/extracted/anno/anno_31_T_GH_2015-08-12.json"

if "annotations" in other.load_json(path):
    print("boo")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-69-b3bceac23dc4> in <module>
#       1 path = "/home/robert/ds-wildfire/data/extracted/anno/anno_31_T_GH_2015-08-12.json"
#       2
# ----> 3 if "annotations" in other.load_json(path):
#       4     print("boo")
#
# NameError: name 'other' is not defined
